# %%
import numpy as np
x=np.array([34,2,45,7,3,2,1,89,54])
np.sort(x, descending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 x=np.array([34,2,45,7,3,2,1,89,54])
# ----> 3 np.sort(x, descending=True)
#
# TypeError: sort() got an unexpected keyword argument 'descending'

# %%
np.sort(data,axis=0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.sort(x[:,[1]],axis=0)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
x=np.array([1,2,3,4,5])
f=[True,False,True,False,True]
x[f]
# Out:
# array([1, 3, 5])

# %%
x=np.array([1,2,3,4,5])
x[x%2!=0]
# Out:
# array([1, 3, 5])

# %% [markdown]
# # The NaN value
