# %% [markdown]
# <!-- TypeCasting / Type Conversion -->
# <!-- two types : 1). Explicit TypeCasting
#                  2). Implicit TypeCasting-->

# %%
a=10  #int
b=3 #float
c=int(a/b)
print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# 10 <class 'int'>
# 3 <class 'int'>
# 3 <class 'int'>

# %%
age=25
print(type(age))

# type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
x="123"
print(x, type(x))

y=float(x)
print(y, type(y))
# Out:
# 123 <class 'str'>
# 123.0 <class 'float'>

# %%
age=input("Enter your age: ")
print("Your age is:", age, type(age))
# Out:
# Your age is: A56 <class 'str'>

# %%
# Simple caluclator
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
sum=num1+num2
difference=num1-num2
product=float(num1*num2)
division=float(num1/num2)
print("Sum:", sum, type(sum))
print("Difference:", difference, type(difference))
print("Product:", product, type(product))
print("Division:", division, type(division))
# Out:
# Sum: 64 <class 'int'>
# Difference: 48 <class 'int'>
# Product: 448.0 <class 'float'>
# Division: 7.0 <class 'float'>
