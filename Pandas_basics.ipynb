# %% [markdown]
# # Topics to be covered
# * > Introduction
# * > Pandas data structure
# * >

# %% [markdown]
# import pandas as pd

# %%
print(pd.__version__)
# Out:
# 3.0.5

# %%
data=[1,2,3,4]
x=pd.Series(data,name="counts")
print(x,type(x))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: counts, dtype: int64 <class 'pandas.Series'>

# %%
index=['a','b','c','d']
data=[1,2,3,4]
x=pd.Series(data,index)
print(x,type(x))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64 <class 'pandas.Series'>

# %%
x.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
y=pd.read_csv(r"C:\Users\aarya\Desktop\stores.csv")
print(y)
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# ...

# %%
import pandas as pd
data=[33,34,40,41,36]
year=[2001,2002,2002,2003,2005,2005]
s=pd.Series(data, index=year, name="data")
print(s)
print(s[2002])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 4
#       2 data=[33,34,40,41,36]
#       3 year=[2001,2002,2002,2003,2005,2005]
# ----> 4 s=pd.Series(data, index=year, name="data")
#       5 print(s)
#       6 print(s[2002])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:503, in Series.__init__(self, data, index, dtype, name, copy)
#     501     index = default_index(len(data))
#     502 elif is_list_like(data):
# --> 503     com.require_length_match(data, index)
#     505 # create/copy the manager
#     506 if isinstance(data, SingleBlockManager):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\common.py:601, in require_length_match(data, index)
# ...

# %%
s.index.is_unique
# Out:
# False

# %%
s.loc[2002]=45

# %%
s.loc[2002]
# Out:
# 2002    45
# 2002    45
# Name: data, dtype: int64

# %%
s.iloc[-1]
# Out:
# np.int64(36)

# %% [markdown]
# # .loc is supposed to be based on index labels and not the positions

# %%
print(s.loc[2002])
print(s[2002])
# Out:
# 2002    45
# 2002    45
# Name: data, dtype: int64
# 2002    45
# 2002    45
# Name: data, dtype: int64

# %% [markdown]
# # .at and .iat
# * > The .at and .iat index accessors are analogous to .loc and .iloc . the difference being that they will return a numpy.ndarray when pulling out a duplicate value, whereas .loc and .iloc return a series

# %%
s.iat[1]
# Out:
# np.int64(45)

# %%
type(s.at[2002])
# Out:
# pandas.Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s.iloc[-3:]
# Out:
# 2003    40
# 2005    41
# 2005    36
# Name: data, dtype: int64

# %%
s.iloc[::-2]
# Out:
# 2005    36
# 2003    40
# 2002    45
# Name: data, dtype: int64

# %%
for item in s.items():
    print(item)
# Out:
# (2002, 45)
# (2002, 45)
# (2003, 40)
# (2005, 41)
# (2005, 36)

# %%
for idx, value in s.items():
    print(idx,value)
# Out:
# 2002 45
# 2002 45
# 2003 40
# 2005 41
# 2005 36

# %% [markdown]
# # .key Method
# * > it's providid as a shortcut to the index as well

# %%
print(s.keys)
for idx in s.keys():
    print(idx)
# Out:
# <bound method Series.keys of 2002    45
# 2002    45
# 2003    40
# 2005    41
# 2005    36
# Name: data, dtype: int64>
# 2002
# 2002
# 2003
# 2005
# 2005

# %%
s1=pd.Series([22,34,45,56],index=['Rahul', 'Bob', 'Joy', 'Tom'], name='Age')
for idx in s1.keys():
    print(idx, "=>", s1[idx])
# Out:
# Rahul => 22
# Bob => 34
# Joy => 45
# Tom => 56

# %% [markdown]
# # Overloaded Operations
